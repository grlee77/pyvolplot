# %%
# %matplotlib inline
import numpy as np

from pyvolplot import volshow

# %% [markdown]
# ## Import a low resolution contrast MRA dataset

# %%
data=np.load('angio3D_downsampled_abs.npz')['angio3D']

# %% [markdown]
# Show maximum intensity projections along each axis

# %%
from matplotlib import pyplot as plt
ax = volshow(data[:,-1::-1,:],mode='mips',notick=True)
